# %%
# !git clone --branch v2.0 https://github.com/tunexlevel/xai-xdl.git
# Out:
# Cloning into 'xai-xdl'...
# remote: Enumerating objects: 361, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 361 (delta 40), reused 60 (delta 22), pack-reused 275 (from 1)
# Receiving objects: 100% (361/361), 132.24 MiB | 27.17 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2026.3.6-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from rdkit) (2.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2026.3.6-cp313-cp313-manylinux_2_28_x86_64.whl (38.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 43.9 MB/s eta 0:00:0000:0100:01
# Installing collected packages: rdkit
# Successfully installed rdkit-2026.3.6

# %%
# %cd /content/xai-xdl
# Out:
# /content/xai-xdl

# %%
# !python train/index.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# CUDA version: 12.8
# GPU memory: 14.56 GB
# ======================================================================
#
# =========================================================================================================================================
# Training Data @ uspto_mit_unmapped_ed_6-6, Batch Size: 32, Epochs: 20, Max Len: 120, Emb Dim: 256, Hidden Dim: 512, Learning Rate: 0.0005
# =========================================================================================================================================
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Dataset: /content/drive/MyDrive/Colab Notebooks/uspto_mit_unmapped.csv
# Number of reactions loaded: 453,374
# Columns: ['reactants', 'products']
# Reactant examples: ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(-c3ccc(N)cc3)cc21.O=CO', 'COCC(C)Oc1cc(Oc2cnc(C(=O)N3CCC3)cn2)cc(C(=O)O)c1.Cc1cnc(N)cn1']
# Product examples: ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(-c3ccc(NC=O)cc3)cc21', 'COCC(C)Oc1cc(Oc2cnc(C(=O)N3CCC3)cn2)cc(C(=O)Nc2cnc(C)cn2)c1']
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# Vocabulary size: 201
# PAD index: 0
# Vocabulary saved to: /content/xai-xdl/tokens
#
# ======================================================================
# CREATING DATASET
# ======================================================================
# Dataset size: 453,374
# Number of batches per epoch: 14,168
#
# ======================================================================
# CREATING MODEL
# ======================================================================
#
# ======================================================================
# CHECKPOINT FOUND
# ======================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Last completed epoch: 16
# Best loss: 0.056924
# Next epoch to train: 17
# ======================================================================
#
# ======================================================================
# STARTING EPOCH 17/20
# ======================================================================
# Epoch 17/20: 100% 14168/14168 [32:20<00:00,  7.30it/s, acc=0.9828, loss=0.0819]
#
# Epoch 17 completed.
# Loss: 0.056011
# Token Accuracy: 0.982846
# Reaction-level Accuracy: 0.597756
#
# NEW BEST MODEL!
# Best loss: 0.056011
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_017.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 0.54 hours
#
# ======================================================================
# STARTING EPOCH 18/20
# ======================================================================
# Epoch 18/20: 100% 14168/14168 [32:21<00:00,  7.30it/s, acc=0.9830, loss=0.0513]
#
# Epoch 18 completed.
# Loss: 0.055360
# Token Accuracy: 0.983033
# Reaction-level Accuracy: 0.600447
#
# NEW BEST MODEL!
# Best loss: 0.055360
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_018.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 1.08 hours
#
# ======================================================================
# STARTING EPOCH 19/20
# ======================================================================
# Epoch 19/20: 100% 14168/14168 [32:19<00:00,  7.30it/s, acc=0.9832, loss=0.0841]
#
# Epoch 19 completed.
# Loss: 0.054637
# Token Accuracy: 0.983227
# Reaction-level Accuracy: 0.604622
#
# NEW BEST MODEL!
# Best loss: 0.054637
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_019.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 1.62 hours
#
# ======================================================================
# STARTING EPOCH 20/20
# ======================================================================
# Epoch 20/20:  25% 3535/14168 [08:03<24:08,  7.34it/s, acc=0.9835, loss=0.0451]
