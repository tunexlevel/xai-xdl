# %%
# !git pull update
# Out:
# fatal: 'update' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !git clone --branch v2.0 https://github.com/tunexlevel/xai-xdl.git
# Out:
# Cloning into 'xai-xdl'...
# remote: Enumerating objects: 366, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 366 (delta 43), reused 65 (delta 25), pack-reused 275 (from 1)
# Receiving objects: 100% (366/366), 132.24 MiB | 15.97 MiB/s, done.
# Resolving deltas: 100% (167/167), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.13/dist-packages (2026.3.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from rdkit) (2.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from rdkit) (11.3.0)

# %%
# %cd /content/xai-xdl
# Out:
# /content/xai-xdl

# %%
# !python train/index.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# CUDA version: 12.8
# GPU memory: 14.56 GB
# ======================================================================
#
# ================================================================================================================================
# Training Data @ ocrtrain_ed_6-6, Batch Size: 256, Epochs: 20, Max Len: 120, Emb Dim: 256, Hidden Dim: 512, Learning Rate: 0.0005
# ================================================================================================================================
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Dataset: /content/drive/MyDrive/Colab Notebooks/ocrtrain.csv
# Number of reactions loaded: 902,581
# Columns: ['reactants', 'products']
# Reactant examples: ['CCS(=O)(=O)Cl.OCCBr', 'CC(C)CS(=O)(=O)Cl.OCCCl']
# Product examples: ['CCS(=O)(=O)OCCBr', 'CC(C)CS(=O)(=O)OCCCl']
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# Vocabulary size: 251
# PAD index: 0
# Vocabulary saved to: /content/xai-xdl/tokens
#
# ======================================================================
# CREATING DATASET
# ======================================================================
# Dataset size: 902,581
# Number of batches per epoch: 3,526
#
# ======================================================================
# CREATING MODEL
# ======================================================================
#
# ======================================================================
# CHECKPOINT FOUND
# ======================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/ocrtrain_ed_6-6/latest.pt
# Last completed epoch: 15
# Best loss: 0.075973
# Next epoch to train: 16
# ======================================================================
#
# ======================================================================
# STARTING EPOCH 16/20
# ======================================================================
# Epoch 16/20:   0% 0/3526 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/xai-xdl/train/index.py", line 582, in <module>
#     output = model(
#         src,
#         tgt[:, :-1]
#     )
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/xai-xdl/mod/model.py", line 80, in forward
#     outs = self.transformer(
#         src=src_emb,
#     ...<5 lines>...
#         memory_key_padding_mask=src_padding_mask,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py", line 289, in forward
#     output = self.decoder(
#         tgt,
#     ...<6 lines>...
#         memory_is_causal=memory_is_causal,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py", line 644, in forward
#     output = mod(
#         output,
#     ...<6 lines>...
#         memory_is_causal=memory_is_causal,
#     )
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py", line 1145, in forward
#     x + self._sa_block(x, tgt_mask, tgt_key_padding_mask, tgt_is_causal)
#         ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/transformer.py", line 1165, in _sa_block
#     x = self.self_attn(
#         ~~~~~~~~~~~~~~^
#         x,
#         ^^
#     ...<5 lines>...
#         need_weights=False,
#         ^^^^^^^^^^^^^^^^^^^
#     )[0]
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/modules/activation.py", line 1492, in forward
#     attn_output, attn_output_weights = F.multi_head_attention_forward(
#                                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         query,
#         ^^^^^^
#     ...<17 lines>...
#         is_causal=is_causal,
#         ^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/functional.py", line 6478, in multi_head_attention_forward
#     q, k, v = _in_projection_packed(query, key, value, in_proj_weight, in_proj_bias)
#               ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/nn/functional.py", line 5836, in _in_projection_packed
#     proj = linear(q, w, b)
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 30.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 25.81 MiB is free. Process 6813 has 2.53 GiB memory in use. Process 26559 has 8.45 GiB memory in use. Including non-PyTorch memory, this process has 3.55 GiB memory in use. Of the allocated memory 3.39 GiB is allocated by PyTorch, and 38.05 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
# %cd /content/xai-xdl
# Out:
# /content/xai-xdl

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.48 KiB | 1.48 MiB/s, done.
# From https://github.com/tunexlevel/xai-xdl
#    29c3dd6..0522f5a  v2.0       -> origin/v2.0
# Updating 29c3dd6..0522f5a
# error: Your local changes to the following files would be overwritten by merge:
# 	train/index.py
# Please commit your changes or stash them before you merge.
# Aborting
