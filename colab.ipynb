# %%
# !git clone --branch v2.0 https://github.com/tunexlevel/xai-xdl.git
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:r-6b13cc65-002c-4b5f-8442-50d759504d00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.13/dist-packages (2026.3.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from rdkit) (2.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from rdkit) (11.3.0)

# %%
# %cd /content/xai-xdl
# Out:
# /content/xai-xdl

# %%
# !python train/index.py
# Out:
# ======================================================================
# DEVICE INFORMATION
# ======================================================================
# Device: cuda
# GPU: Tesla T4
# CUDA version: 12.8
# GPU memory: 14.56 GB
# ======================================================================
#
# =========================================================================================================================================
# Training Data @ uspto_mit_unmapped_ed_6-6, Batch Size: 32, Epochs: 20, Max Len: 120, Emb Dim: 256, Hidden Dim: 512, Learning Rate: 0.0005
# =========================================================================================================================================
#
# ======================================================================
# LOADING DATASET
# ======================================================================
# Dataset: /content/drive/MyDrive/Colab Notebooks/uspto_mit_unmapped.csv
# Number of reactions loaded: 453,374
# Columns: ['reactants', 'products']
# Reactant examples: ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(-c3ccc(N)cc3)cc21.O=CO', 'COCC(C)Oc1cc(Oc2cnc(C(=O)N3CCC3)cn2)cc(C(=O)O)c1.Cc1cnc(N)cn1']
# Product examples: ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(-c3ccc(NC=O)cc3)cc21', 'COCC(C)Oc1cc(Oc2cnc(C(=O)N3CCC3)cn2)cc(C(=O)Nc2cnc(C)cn2)c1']
#
# ======================================================================
# BUILDING VOCABULARY
# ======================================================================
# Vocabulary size: 201
# PAD index: 0
# Vocabulary saved to: /content/xai-xdl/tokens
#
# ======================================================================
# CREATING DATASET
# ======================================================================
# Dataset size: 453,374
# Number of batches per epoch: 14,168
#
# ======================================================================
# CREATING MODEL
# ======================================================================
#
# ======================================================================
# CHECKPOINT FOUND
# ======================================================================
# Checkpoint: /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Last completed epoch: 12
# Best loss: 0.061581
# Next epoch to train: 13
# ======================================================================
#
# ======================================================================
# STARTING EPOCH 13/20
# ======================================================================
# Epoch 13/20: 100% 14168/14168 [1:47:16<00:00,  2.20it/s, acc=0.9815, loss=0.0804]
#
# Epoch 13 completed.
# Loss: 0.060039
# Token Accuracy: 0.981536
# Reaction-level Accuracy: 0.577821
#
# NEW BEST MODEL!
# Best loss: 0.060039
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_013.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 1.79 hours
#
# ======================================================================
# STARTING EPOCH 14/20
# ======================================================================
# Epoch 14/20: 100% 14168/14168 [1:47:18<00:00,  2.20it/s, acc=0.9819, loss=0.0963]
#
# Epoch 14 completed.
# Loss: 0.058852
# Token Accuracy: 0.981923
# Reaction-level Accuracy: 0.583893
#
# NEW BEST MODEL!
# Best loss: 0.058852
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_014.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 3.58 hours
#
# ======================================================================
# STARTING EPOCH 15/20
# ======================================================================
# Epoch 15/20: 100% 14168/14168 [1:47:13<00:00,  2.20it/s, acc=0.9823, loss=0.0841]
#
# Epoch 15 completed.
# Loss: 0.057640
# Token Accuracy: 0.982295
# Reaction-level Accuracy: 0.589738
#
# NEW BEST MODEL!
# Best loss: 0.057640
#
# Latest checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/latest.pt
# Epoch checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/epoch_015.pt
#
# Best checkpoint saved:
# /content/drive/MyDrive/Colab Notebooks/ChemXAI/checkpoints/uspto_mit_unmapped_ed_6-6/best.pt
#
# GPU memory allocated: 0.14 GB
# GPU memory reserved: 1.28 GB
#
# Elapsed training time: 5.36 hours
#
# ======================================================================
# STARTING EPOCH 16/20
# ======================================================================
# Epoch 16/20:  28% 3923/14168 [29:40<1:16:35,  2.23it/s, acc=0.9826, loss=0.0424]
